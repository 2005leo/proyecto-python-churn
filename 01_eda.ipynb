# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
df = pd.read_csv(C:\Proyectos\proyecto-python-churn\data\raw\churn_synthetic.csv)
df.head()
df["churn"].mean()  # tasa base

sns.countplot(data=df, x="contract_type", hue="churn"); plt.title("Contract × Churn"); plt.show()
sns.histplot(data=df, x="monthly_charges", hue="churn", kde=True); plt.title("Charges × Churn"); plt.show()
sns.scatterplot(data=df, x="app_logins_30d", y="support_tickets_90d", hue="churn", alpha=.4); plt.show()
# Out:
#   Cell In[5], line 2
#     df = pd.read_csv(C:\Proyectos\proyecto-python-churn\data\raw\churn_synthetic.csv)
#                       ^
# SyntaxError: invalid syntax
